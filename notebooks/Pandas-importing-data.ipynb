# %% [markdown]
# # Importing and analysing data in Python with Pandas
#
# This notebook shows how to import and work with data using Python and its Pandas library. It is based on a tutorial at [First Python Notebook](http://www.firstpythonnotebook.org/dataframe/index.html)

# %%
import pandas as pd
#More details on this file at http://www.firstpythonnotebook.org/dataframe/index.html
props = pd.read_csv("http://www.firstpythonnotebook.org/_static/committees.csv")

# %% [markdown]
# ## This is now a dataframe
#
# When imported from a CSV, the variable created is a **DataFrame**. The equivalent in R is called a **data frame** (note the space).
#
# We can use methods to analyse that data, just as you can in R. For example the `head()` method shows the first few rows:

# %%
props.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 3  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 4  ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
#
#    ccdc_prop_id                                          prop_name  \
# 0            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 3            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 4            71  PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                382                 1374469
# 1                383                 1220380
# 2                384                 1282321
# 3                385                 1382843
# 4                386                 1362973
#
#                                       committee_name committee_position
# 0  YES ON PROPOSITION 51 - CALIFORNIANS FOR QUALI...            SUPPORT
# 1  COMMUNITY COLLEGE FACILITY COALITION ISSUES CO...            SUPPORT
# 2  TORLAKSON'S INVEST IN CALIFORNIA A BALLOT MEAS...            SUPPORT
# 3  CALIFORNIA TAXPAYERS AND EDUCATORS OPPOSED TO ...             OPPOSE
# 4  YES ON PROPOSITION 52 - A COALITION OF CALIFOR...            SUPPORT

# %% [markdown]
# In a similar way you can show info about all the columns:

# %%
props.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 8 columns):
# ocd_prop_id               102 non-null object
# calaccess_prop_id         102 non-null int64
# ccdc_prop_id              102 non-null int64
# prop_name                 102 non-null object
# ccdc_committee_id         102 non-null int64
# calaccess_committee_id    102 non-null int64
# committee_name            102 non-null object
# committee_position        102 non-null object
# dtypes: int64(4), object(4)
# memory usage: 6.4+ KB

# %% [markdown]
# As before, you can type the name of the variable, a period and then TAB to see methods you can use on that object (e.g. `props.` and then TAB). First let's get some different data:

# %%
#Import some different but related data
contribs = pd.read_csv("http://www.firstpythonnotebook.org/_static/contributions.csv")
#Now let's see the headings:
contribs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56379 entries, 0 to 56378
# Data columns (total 13 columns):
# calaccess_committee_id          56379 non-null int64
# committee_name                  56379 non-null object
# calaccess_filing_id             56379 non-null int64
# date_received                   56379 non-null object
# contributor_lastname            56375 non-null object
# contributor_firstname           53411 non-null object
# contributor_city                56369 non-null object
# contributor_state               56363 non-null object
# contributor_zip                 56366 non-null object
# contributor_employer            48572 non-null object
# contributor_occupation          53273 non-null object
# contributor_is_self_employed    56379 non-null bool
# amount                          56379 non-null float64
# dtypes: bool(1), float64(1), int64(2), object(9)
# memory usage: 5.2+ MB

# %% [markdown]
# You can pull a column in - as a **series** - by adding it after a period:

# %%
propnames = props.prop_name

# %% [markdown]
# ## Pandas' version of a pivot table - counting occurrences
#
# The `value_counts()` method will generate a count of values in a *series* variable, or in the column of a dataframe:

# %%
#Counting frequency of values in a dataframe column
props.prop_name.value_counts()
#Counting frequency in a series variable
propnames.value_counts()
# Out:
# PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE CRIMINAL PROCEEDINGS AND SENTENCING. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.                           13
# PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTHCARE, TOBACCO USE PREVENTION, RESEARCH, AND LAW ENFORCEMENT. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.    12
# PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.                                                                                                   11
# PROPOSITION 066- DEATH PENALTY. PROCEDURES. INITIATIVE STATUTE.                                                                                                 9
# PROPOSITION 055 - TAX EXTENSION TO FUND EDUCATION AND HEALTHCARE. INITIATIVE CONSTITUTIONAL AMENDMENT.                                                          8
# PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON SINGLE-USE PLASTIC BAGS.                                                                                         7
# PROPOSITION 062- DEATH PENALTY. INITIATIVE STATUTE.                                                                                                             7
# PROPOSITION 059- SB 254 (CHAPTER 20, STATUTES OF 2016), ALLEN. CAMPAIGN FINANCE: VOTER INSTRUCTION                                                              6
# PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOTER APPROVAL. INITIATIVE CONSTITUTIONAL AMENDMENT.                                                                 4
# PROPOSITION 054 - LEGISLATURE. LEGISLATION AND PROCEEDINGS. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.                                                    4
# PROPOSITION 058 - SB 1174 (CHAPTER 753, STATUTES OF 2014), LARA. ENGLISH LANGUAGE EDUCATION                                                                     4
# PROPOSITION 063- FIREARMS. AMMUNITION SALES. INTIATIVE STATUTE.                                                                                                 4
# PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-12 SCHOOL AND COMMUNITY COLLEGE FACILITIES. INITIATIVE STATUTORY AMENDMENT.                                       4
# PROPOSITION 052 - STATE FEES ON HOSPITALS. FEDERAL MEDI-CAL MATCHING FUNDS. INITIATIVE STATUTORY AND CONSTITUTIONAL AMENDMENT.                                  3
# PROPOSITION 061- STATE PRESCRIPTION DRUG PURCHASES. PRICING STANDARDS. INITIATIVE STATUTE.                                                                      3
# PROPOSITION 060- ADULT FILMS. CONDOMS. HEALTH REQUIREMENTS. INITIATIVE STATUTE.                                                                                 2
# PROPOSITION 065- CARRY-OUT BAGS. CHARGES. INITIATIVE STATUTE.                                                                                                   1
# Name: prop_name, dtype: int64

# %% [markdown]
# We can order and make it into a proper pivot table (i.e. a *dataframe*) using `reset_index()`

# %%
propnames.value_counts().reset_index()
# Out:
#                                                 index  prop_name
# 0   PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...         13
# 1   PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...         12
# 2   PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...         11
# 3   PROPOSITION 066- DEATH PENALTY. PROCEDURES. IN...          9
# 4   PROPOSITION 055 - TAX EXTENSION TO FUND EDUCAT...          8
# 5   PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...          7
# 6   PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...          7
# 7   PROPOSITION 059- SB 254 (CHAPTER 20, STATUTES ...          6
# 8   PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...          4
# 9   PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...          4
# 10  PROPOSITION 058 - SB 1174 (CHAPTER 753, STATUT...          4
# 11  PROPOSITION 063- FIREARMS. AMMUNITION SALES. I...          4
# 12  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...          4
# 13  PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...          3
# 14  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...          3
# 15  PROPOSITION 060- ADULT FILMS. CONDOMS. HEALTH ...          2
# 16  PROPOSITION 065- CARRY-OUT BAGS. CHARGES. INIT...          1

# %% [markdown]
# ## Filtering (SQL style queries) - indexing
#
# We can add a filter by putting an **expression** in *square brackets* after the dataframe name like so:

# %%
marijuanamatches = props[props.prop_name == 'PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.']
marijuanamatches.head()
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 74  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 75  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 76  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 77  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 78  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
#
#     ccdc_prop_id                                          prop_name  \
# 74            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 75            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 76            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 77            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 78            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
#
#     ccdc_committee_id  calaccess_committee_id  \
# 74                456                 1381808
# 75                457                 1382525
# 76                458                 1376077
# 77                459                 1382568
# 78                460                 1371855
#
#                                        committee_name committee_position
# 74  YES ON 64, CALIFORNIANS TO CONTROL, REGULATE A...            SUPPORT
# 75                             NEW APPROACH PAC (MPO)            SUPPORT
# 76  CALIFORNIANS FOR SENSIBLE REFORM, SPONSORED BY...            SUPPORT
# 77  PUBLIC AND MENTAL HEALTH ADVOCATES AGAINST 64,...             OPPOSE
# 78  MARIJUANA POLICY PROJECT OF CALIFORNIA, YES ON 64            SUPPORT

# %% [markdown]
# ## Merging datasets
#
# The `merge` method needs the names of the two dataframes and the column being merged on. The example below is straightforward because the column in common has the same name in both dataframes. However, that's not always the case. See the [documentation](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.merge.html) for more, but basically you need to use `left_on=` and `right_on=` to specify the names in the two datasets. You can also find [more examples in this post](https://chrisalbon.com/python/pandas_join_merge_dataframe.html).

# %%
merged = pd.merge(props, contribs, on="calaccess_committee_id")
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 90264 entries, 0 to 90263
# Data columns (total 20 columns):
# ocd_prop_id                     90264 non-null object
# calaccess_prop_id               90264 non-null int64
# ccdc_prop_id                    90264 non-null int64
# prop_name                       90264 non-null object
# ccdc_committee_id               90264 non-null int64
# calaccess_committee_id          90264 non-null int64
# committee_name_x                90264 non-null object
# committee_position              90264 non-null object
# committee_name_y                90264 non-null object
# calaccess_filing_id             90264 non-null int64
# date_received                   90264 non-null object
# contributor_lastname            90256 non-null object
# contributor_firstname           86685 non-null object
# contributor_city                90251 non-null object
# contributor_state               90244 non-null object
# contributor_zip                 90248 non-null object
# contributor_employer            81684 non-null object
# contributor_occupation          86545 non-null object
# contributor_is_self_employed    90264 non-null bool
# amount                          90264 non-null float64
# dtypes: bool(1), float64(1), int64(5), object(13)
# memory usage: 13.9+ MB

# %% [markdown]
# Now you can perform different calculations on the merged dataset, such as a grand total:

# %%
merged.amount.sum()
# Out:
# 466851993.3900001

# %% [markdown]
# ## Creating filtered subsets of data
#
# Here we create two new variables containing a subset of the merged dataset where the position is support, and where the position is oppose.
#
# Those two subsets are then used to calculate totals.

# %%
support = merged[merged.committee_position == 'SUPPORT']
oppose = merged[merged.committee_position == 'OPPOSE']
#Total the amounts in the oppose subset
oppose.amount.sum()
# Out:
# 226772758.05000007

# %%
#Total the amounts in the support subset
support.amount.sum()
# Out:
# 240079235.34000006

# %%
#Divide the amounts given to supporters by the total of all
support.amount.sum() / merged.amount.sum()
# Out:
# 0.51425128036123002

# %% [markdown]
# ## Sorting datasets
#
# We can sort the dataset by using `.sort_values` with the column to sort by specified in parentheses. Note that the column name is in quotations as a string. By default it sorts ascending, so you can add an extra parameter to specify that that default should be overridden:

# %%
merged.sort_values("amount", ascending=False)
# Out:
#                                             ocd_prop_id  calaccess_prop_id  \
# 1863   ocd-contest/446ec3da-7de1-45f0-9f97-228e53c6a9f6            1382647
# 1865   ocd-contest/446ec3da-7de1-45f0-9f97-228e53c6a9f6            1382647
# 1972   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 1979   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 2026   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 1967   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 1851   ocd-contest/446ec3da-7de1-45f0-9f97-228e53c6a9f6            1382647
# 1547   ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 1973   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 1980   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 1968   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 3087   ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 3046   ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 3075   ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 3193   ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 3653   ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 3080   ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 3066   ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 3055   ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 3053   ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 1850   ocd-contest/446ec3da-7de1-45f0-9f97-228e53c6a9f6            1382647
# 3089   ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 83179  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 2062   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 3161   ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
#
ES ON 55 - CALIFORNIANS FOR BUDGET STABILITY,...            SUPPORT
# 3040   NO ON PROP 61 - CALIFORNIANS AGAINST THE DECEP...             OPPOSE
# 3070   NO ON PROP 61 - CALIFORNIANS AGAINST THE DECEP...             OPPOSE
# 3061   NO ON PROP 61 - CALIFORNIANS AGAINST THE DECEP...             OPPOSE
# ...                                                  ...                ...
# 79106  NEWSOM BALLOT MEASURE COMMITTEE; SAFETY FOR AL...            SUPPORT
# 81730  NEWSOM BALLOT MEASURE COMMITTEE; SAFETY FOR AL...            SUPPORT
# 77759  NEWSOM BALLOT MEASURE COMMITTEE; SAFETY FOR AL...            SUPPORT
# 76267  STOP PROP 63, A GRASSROOTS, COMMON-SENSE EFFOR...             OPPOSE
# 2924                 OVERTURN CITIZENS UNITED, YES ON 59            SUPPORT
# 80549  NEWSOM BALLOT MEASURE COMMITTEE; SAFETY FOR AL...            SUPPORT
# 11451  YES ON 62, NO ON 66. REPLACE THE COSTLY, FAILE...             OPPOSE
# 7346   YES ON 62, NO ON 66. REPLACE THE COSTLY, FAILE...            SUPPORT
# 78690  NEWSOM BALLOT MEASURE COMMITTEE; SAFETY FOR AL...            SUPPORT
# 80782  NEWSOM BALLOT MEASURE COMMITTEE; SAFETY FOR AL...            SUPPORT
# 74987  STOP PROP 63, A GRASSROOTS, COMMON-SENSE EFFOR...             OPPOSE
# 2293   NO ON 57 - STOP EARLY RELEASE OF VIOLENT CRIMI...             OPPOSE
# 78205  NEWSOM BALLOT MEASURE COMMITTEE; SAFETY FOR AL...            SUPPORT
# 75590  STOP PROP 63, A GRASSROOTS, COMMON-SENSE EFFOR...             OPPOSE
# 81256  NEWSOM BALLOT MEASURE COMMITTEE; SAFETY FOR AL...            SUPPORT
# 2629                 OVERTURN CITIZENS UNITED, YES ON 59            SUPPORT
# 83830  CALIFORNIANS FOR RESPONSIBLE MARIJUANA REFORM,...            SUPPORT
# 75591  STOP PROP 63, A GRASSROOTS, COMMON-SENSE EFFOR...             OPPOSE
# 70638  CALIFORNIANS TO MEND, NOT END, THE DEATH PENAL...            SUPPORT
# 2973   NO ON PROPOSITION 60, CALIFORNIANS AGAINST WOR...             OPPOSE
# 69624  CALIFORNIANS TO MEND, NOT END, THE DEATH PENAL...             OPPOSE
# 70870  CALIFORNIANS TO MEND, NOT END, THE DEATH PENAL...            SUPPORT
# 69856  CALIFORNIANS TO MEND, NOT END, THE DEATH PENAL...             OPPOSE
# 75328  STOP PROP 63, A GRASSROOTS, COMMON-SENSE EFFOR...             OPPOSE
# 77522  NEWSOM BALLOT MEASURE COMMITTEE; SAFETY FOR AL...            SUPPORT
# 79618  NEWSOM BALLOT MEASURE COMMITTEE; SAFETY FOR AL...            SUPPORT
# 865    YES ON PROPOSITION 51 - CALIFORNIANS FOR QUALI...            SUPPORT
# 74164  COALITION FOR CIVIL LIBERTIES - NO ON 63, A PR...             OPPOSE
# 864    YES ON PROPOSITION 51 - CALIFORNIANS FOR QUALI...            SUPPORT
# 83297  CALIFORNIANS FOR SENSIBLE REFORM, SPONSORED BY...            SUPPORT
#
#                                         committee_name_y  calaccess_filing_id  \
# 1863   YES ON 55 - CALIFORNIANS FOR BUDGET STABILITY,...              2083690
# 1865   YES ON 55 - CALIFORNIANS FOR BUDGET STABILITY,...              2083690
# 1972   NO ON 56 - STOP THE SPECIAL INTEREST TAX GRAB....              2083642
# 1979   NO ON 56 - STOP THE SPECIAL INTEREST TAX GRAB....              2083642
# 2026   YES ON 56 - SAVES LIVES CALIFORNIA, A COALITIO...              2098627
# 1967   NO ON 56 - STOP THE SPECIAL INTEREST TAX GRAB....              2083642
# 1851   YES ON 55 - CALIFORNIANS FOR BUDGET STABILITY,...              2038482
# 1547   YES ON PROPOSITION 52 - A COALITION OF CALIFOR...              2033916
# 1973   NO ON 56 - STOP THE SPECIAL INTEREST TAX GRAB....              2083642
# 1980   NO ON 56 - STOP THE SPECIAL INTEREST TAX GRAB....              2083642
# 1968   NO ON 56 - STOP THE SPECIAL INTEREST TAX GRAB....              2083642
# 3087   NO ON PROP 61 - CALIFORNIANS AGAINST THE DECEP...              2064695
# 3046   NO ON PROP 61 - CALIFORNIANS AGAINST THE DECEP...              1998299
# 3075   NO ON PROP 61 - CALIFORNIANS AGAINST THE DECEP...              2013042
# 3193   YES ON PROP 61, CALIFORNIANS FOR LOWER DRUG PR...              2054483
# 3653   YES ON PROP 61, CALIFORNIANS FOR LOWER DRUG PR...              2083732
# 3080   NO ON PROP 61 - CALIFORNIANS AGAINST THE DECEP...              2036765
# 3066   NO ON PROP 61 - CALIFORNIANS AGAINST THE DECEP...              2013042
# 3055   NO ON PROP 61 - CALIFORNIANS AGAINST THE DECEP...              2013042
# 3053   NO ON PROP 61 - CALIFORNIANS AGAINST THE DECEP...              2013042
# 1850   YES ON 55 - CALIFORNIANS FOR BUDGET STABILITY,...              2038482
# 3089   NO ON PROP 61 - CALIFORNIANS AGAINST THE DECEP...              2064695
# 83179  YES ON 64, CALIFORNIANS TO CONTROL, REGULATE A...              2083528
# 2062   YES ON 56 - SAVES LIVES CALIFORNIA, A COALITIO...              2130961
# 3161   YES ON PROP 61, CALIFORNIANS FOR LOWER DRUG PR...              2013255
# 1550   CALIFORNIANS FOR HOSPITAL ACCOUNTABILITY AND Q...              2012153
# 1859   YES ON 55 - CALIFORNIANS FOR BUDGET STABILITY,
# 3046                    NaN    NEW BRUNSWICK                NJ
# 3075                    NaN         NEW YORK                NY
# 3193                    NaN      LOS ANGELES                CA
# 3653                    NaN      LOS ANGELES                CA
# 3080                    NaN      BRIDGEWATER                NJ
# 3066                    NaN       WILMINGTON                DE
# 3055                    NaN    THOUSAND OAKS                CA
# 3053                    NaN          CHICAGO                IL
# 1850                    NaN       SACRAMENTO                CA
# 3089                    NaN      FOSTER CITY                CA
# 83179                  SEAN        PALO ALTO                CA
# 2062              THOMAS F.    SAN FRANCISCO                CA
# 3161                    NaN      LOS ANGELES                CA
# 1550                    NaN         COMMERCE                CA
# 1859                    NaN       BURLINGAME                CA
# 3040                    NaN         NEW YORK                NY
# 3070                    NaN         NEW YORK                NY
# 3061                    NaN     INDIANAPOLIS                IN
# ...                     ...              ...               ...
# 79106                GEORGE         BERKELEY                CA
# 81730               SHANNON        LOS GATOS                CA
# 77759               RUSSELL         CORONADO                CA
# 76267               WILLIAM           PHELAN                CA
# 2924               JENNIFER           SEDONA                AZ
# 80549              TERRENCE        BRADENTON                FL
# 11451                MICKEY       SACRAMENTO                CA
# 7346                 MICKEY       SACRAMENTO                CA
# 78690                KATHIE     CAROL STREAM                IL
# 80782               COLLEEN      LOS ANGELES                CA
# 74987                   TOM    SAN FRANCISCO                CA
# 2293                 JOHNNY         PALMDALE                CA
# 78205                CECELE        PALO ALTO                CA
# 75590                ROBERT         SAN JOSE                CA
# 81256                BONNIE    SAN FRANCISCO                CA
# 2629                  DONNA           VENICE                CA
# 83830                 PETER    SAN FRANCISCO                CA
# 75591                  JOHN         MOORPARK                CA
# 70638               LYNN A.      LOS ANGELES                CA
# 2973                   PHIL       WASHINGTON                DC
# 69624               LYNN A.      LOS ANGELES                CA
# 70870               LYNN A.      LOS ANGELES                CA
# 69856               LYNN A.      LOS ANGELES                CA
# 75328                CARRIE        ELK GROVE                CA
# 77522                DWIGHT      SPRING CITY                PA
# 79618                GEORGE         ATHERTON                CA
# 865                     NaN       SAN RAFAEL                CA
# 74164                   NaN       SACRAMENTO                CA
# 864                     NaN       SACRAMENTO                CA
# 83297                   NaN           IRVINE                CA
#
#       contributor_zip                 contributor_employer  \
# 1863            95814                                  NaN
# 1865            94010                                  NaN
# 1972            95814                                  NaN
# 1979            95814                                  NaN
# 2026            95814                                  NaN
# 1967            95814                                  NaN
# 1851            95814                                  NaN
# 1547            91107                                  NaN
# 1973            27101                                  NaN
# 1980            27101                                  NaN
# 1968            27101                                  NaN
# 3087             7033                                  NaN
# 3046             8933                                  NaN
# 3075            10017                                  NaN
# 3193            90028                                  NaN
# 3653            90028                                  NaN
# 3080             8807                                  NaN
# 3066            19850                                  NaN
# 3055            91320                                  NaN
# 3053            60064                                  NaN
# 1850            95814                                  NaN
# 3089            94404                                  NaN
# 83179           94301                                  NaN
# 2062            94104                      NEXTGEN CLIMATE
# 3161            90028                                  NaN
# 1550       90022-5119                                  NaN
# 1859            94010                                  NaN
# 3040            10154                                  NaN
# 3070            10169                                  NaN
# 3061            46285                                  NaN
# ...               ...                                  ...
# 79106           94618   UNIVERSITY OF CALIFORNIA, BERKELEY
# 81730           95030                                  NaN
# 77759           92178                MCKEE PRIVATE CAPITAL
# 76267           92329                          POSTED IND.
# 2924            86339                                 SELF
# 80549           34202                   TERRENCE GRYWINSKI
# 11451           95818                    SACRAMENTO COUNTY
# 7346            95818                    SACRAMENTO COUNTY
# 78690           60188                                  NaN
# 80782           90049                     RPD CATALYST LLC
# 74987           94116                      SPORTS BASEMENT
# 2293            93550  WESTERN PACIFIC ROOFING CORPORATION
# 78205           94301                  STANFORD UNIVERSITY
# 75590           95126          SELF EMPLOYED - ROBERT HILL
# 81256           94127                                  NaN
# 2629            90291                                 SELF
# 83830           94114                          APPLE, INC.
# 75591           93021                   SECURITIES AMERICA
# 70638           90077                                  NaN
# 2973            20005                  DKT LIBERTY PROJECT
# 69624           90077                                  NaN
# 70870           90077                                  NaN
# 69856           90077                                  NaN
# 75328           95624                                  NaN
# 77522           19475                                  NaN
# 79618           94027                       BAIN & COMPANY
# 865             94901                                  NaN
# 74164           95833                                  NaN
# 864             95814                                  NaN
# 83297           92618                                  NaN
#
#                   contributor_occupation  contributor_is_self_employed  \
# 1863                                 NaN                         False
# 1865                                 NaN                         False
# 1972                                 NaN                         False
# 1979                                 NaN                         False
# 2026                                 NaN                         False
# 1967                                 NaN                         False
# 1851                                 NaN                         False
# 1547                                 NaN                         False
# 1973                                 NaN                         False
# 1980                                 NaN                         False
# 1968                                 NaN                         False
# 3087                                 NaN                         False
# 3046                                 NaN                         False
# 3075                                 NaN                         False
# 3193                                 NaN                         False
# 3653                                 NaN                         False
# 3080                                 NaN                         False
# 3066                                 NaN                         False
# 3055                                 NaN                         False
# 3053                                 NaN                         False
# 1850                                 NaN                         False
# 3089                                 NaN                         False
# 83179                                NaN                         False
# 2062               PRESIDENT AND FOUNDER                         False
# 3161                                 NaN                         False
# 1550                                 NaN                         False
# 1859                                 NaN                         False
# 3040                                 NaN                         False
# 3070                                 NaN                         False
# 3061                                 NaN                         False
# ...                                  ...                           ...
# 79106                            FACULTY                         False
# 81730                       NOT EMPLOYED                         False
# 77759                      ASSET MANAGER                         False
# 76267                              SALES                         False
# 2924                          CONSULTANT                         False
# 80549             CRANIOSACRAL THERAPIST                         False
# 11451                    PUBLIC DEFENDER                         False
# 7346                     PUBLIC DEFENDER                         False
# 78690                       NOT EMPLOYED                         False
# 80782                           ATTORNEY                         False
# 74987                              SALES                         False
# 2293   ROOFING AND SHEETMETAL CONTRACTOR                         False
# 78205             ACADEMIC ADMINISTRATOR                         False
# 75590              INFORMATION REQUESTED                         False
# 81256                       NOT EMPLOYED                         False
# 2629                                 MOM                         False
# 83830                         PROGRAMMER                         False
# 75591                  FINANCIAL ADVISOR                         False
# 70638                          HOMEMAKER                         False
# 2973                               OWNER                         False
# 69624                          HOMEMAKER                         False
# 70870                          HOMEMAKER                         False
# 69856                          HOMEMAKER                         False
# 75328                          HOMEMAKER                         False
# 77522                       NOT EMPLOYED                         False
# 79618              MANAGEMENT CONSULTANT                         False
# 865                                  NaN                         False
# 74164                                NaN                         False
# 864                                  NaN                         False
# 83297                                NaN                         False
#
#             amount
# 1863   12500000.00
# 1865   10000000.00
# 1972    9956700.00
# 1979    9904752.00
# 2026    9000000.00
# 1967    8588736.00
# 1851    8500000.00
# 1547    8478390.00
# 1973    7050000.00
# 1980    7010000.00
# 1968    6080000.00
# 3087    5860000.00
# 3046    5700000.00
# 3075    5700000.00
# 3193    5000000.00
# 3653    5000000.00
# 3080    4150000.00
# 3066    4150000.00
# 3055    4150000.00
# 3053    4150000.00
# 1850    4000000.00
# 3089    4000000.00
# 83179   4000000.00
# 2062    3500000.00
# 3161    3000000.00
# 1550    3000000.00
# 1859    3000000.00
# 3040    2880000.00
# 3070    2880000.00
# 3061    2800000.00
# ...            ...
# 79106      -100.00
# 81730      -100.00
# 77759      -100.00
# 76267      -100.00
# 2924       -109.34
# 80549      -250.00
# 11451      -250.00
# 7346       -250.00
# 78690      -250.00
# 80782      -300.00
# 74987      -450.00
# 2293       -500.00
# 78205      -500.00
# 75590      -500.00
# 81256      -500.00
# 2629       -900.00
# 83830      -900.00
# 75591     -1000.00
# 70638     -1000.00
# 2973      -1000.00
# 69624     -1000.00
# 70870     -1000.00
# 69856     -1000.00
# 75328     -2450.00
# 77522     -2500.00
# 79618     -5000.00
# 865       -9000.00
# 74164    -15000.00
# 864      -27000.00
# 83297   -150000.00
#
# [90264 rows x 20 columns]

# %%
#Repeating the process on the support dataset, and only showing the first 5 results using .head()
support.sort_values("amount", ascending=False).head()
# Out:
#                                            ocd_prop_id  calaccess_prop_id  \
# 1863  ocd-contest/446ec3da-7de1-45f0-9f97-228e53c6a9f6            1382647
# 1865  ocd-contest/446ec3da-7de1-45f0-9f97-228e53c6a9f6            1382647
# 2026  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 1851  ocd-contest/446ec3da-7de1-45f0-9f97-228e53c6a9f6            1382647
# 1547  ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
#
#       ccdc_prop_id                                          prop_name  \
# 1863            74  PROPOSITION 055 - TAX EXTENSION TO FUND EDUCAT...
# 1865            74  PROPOSITION 055 - TAX EXTENSION TO FUND EDUCAT...
# 2026            75  PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...
# 1851            74  PROPOSITION 055 - TAX EXTENSION TO FUND EDUCAT...
# 1547            71  PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
#
#       ccdc_committee_id  calaccess_committee_id  \
# 1863                398                 1381382
# 1865                398                 1381382
# 2026                408                 1377991
# 1851                398                 1381382
# 1547                386                 1362973
#
#                                        committee_name_x committee_position  \
# 1863  YES ON 55 - CALIFORNIANS FOR BUDGET STABILITY,...            SUPPORT
# 1865  YES ON 55 - CALIFORNIANS FOR BUDGET STABILITY,...            SUPPORT
# 2026  YES ON 56 - SAVES LIVES CALIFORNIA, A COALITIO...            SUPPORT
# 1851  YES ON 55 - CALIFORNIANS FOR BUDGET STABILITY,...            SUPPORT
# 1547  YES ON PROPOSITION 52 - A COALITION OF CALIFOR...            SUPPORT
#
#                                        committee_name_y  calaccess_filing_id  \
# 1863  YES ON 55 - CALIFORNIANS FOR BUDGET STABILITY,...              2083690
# 1865  YES ON 55 - CALIFORNIANS FOR BUDGET STABILITY,...              2083690
# 2026  YES ON 56 - SAVES LIVES CALIFORNIA, A COALITIO...              2098627
# 1851  YES ON 55 - CALIFORNIANS FOR BUDGET STABILITY,...              2038482
# 1547  YES ON PROPOSITION 52 - A COALITION OF CALIFOR...              2033916
#
#      date_received                               contributor_lastname  \
# 1863    2016-07-21  CALIFORNIA HOSPITALS COMMITTEE ON ISSUES, (CHC...
# 1865    2016-07-15         CALIFORNIA TEACHERS ASSOCIATION/ISSUES PAC
# 2026    2016-10-11  CA HOSPITALS COMMITTEE ON ISSUES, (CHCI) SPONS...
# 1851    2016-03-23  CALIFORNIA HOSPITALS COMMITTEE ON ISSUES, (CHC...
# 1547    2016-01-20                                     DIGNITY HEALTH
#
#      contributor_firstname contributor_city contributor_state contributor_zip  \
# 1863                   NaN       SACRAMENTO                CA           95814
# 1865                   NaN       BURLINGAME                CA           94010
# 2026                   NaN       SACRAMENTO                CA           95814
# 1851                   NaN       SACRAMENTO                CA           95814
# 1547                   NaN    SAN FRANCISCO                CA           91107
#
#      contributor_employer contributor_occupation  \
# 1863                  NaN                    NaN
# 1865                  NaN                    NaN
# 2026                  NaN                    NaN
# 1851                  NaN                    NaN
# 1547                  NaN                    NaN
#
#       contributor_is_self_employed      amount
# 1863                         False  12500000.0
# 1865                         False  10000000.0
# 2026                         False   9000000.0
# 1851                         False   8500000.0
# 1547                         False   8478390.0

# %% [markdown]
# ## Grouping by (pivot tables again) columns
#
# You can use `groupby` to create a pivot table based on a calculation rather than a count. The order is:
#
# 1. Dataset name - in this case `merged`
# 2. Followed by method `.groupby()` specifying the field to be grouped on (the rows in a pivot table)
# 3. Followed by the field you want to calculate on (the values in a pivot table) - in this case, `.amount`
# 4. Followed by the method to be applied to be applied to that field (`.sum()` in this case)
# 5. Add `.reset_index()` to make it a proper table
# 6. You can also add a `.sort_values()` if you want to order it
#
# Below I've also added `.head()` so it doesn't take up too much space

# %%
merged.groupby("committee_name_x").amount.sum().reset_index().sort_values("amount", ascending=False).head()
# Out:
#                                      committee_name_x       amount
# 34  NO ON PROP 61 - CALIFORNIANS AGAINST THE DECEP...  108417232.0
# 31  NO ON 56 - STOP THE SPECIAL INTEREST TAX GRAB....   54650500.0
# 53  YES ON 55 - CALIFORNIANS FOR BUDGET STABILITY,...   53494750.0
# 54  YES ON 56 - SAVES LIVES CALIFORNIA, A COALITIO...   29267861.0
# 20       FUND FOR POLICY REFORM (NONPROFIT 501(C)(4))   24560000.0

# %% [markdown]
# Multiple fields can be added by using square brackets like so:

# %%
merged.groupby(["committee_name_x","contributor_firstname","contributor_lastname"]).amount.sum().reset_index().sort_values("amount", ascending=False).head()
# Out:
#                                         committee_name_x  \
# 36927  YES ON 56 - SAVES LIVES CALIFORNIA, A COALITIO...
# 30170  MILLION VOTER PROJECT ACTION FUND - YES ON 55,...
# 38463  YES ON 64, CALIFORNIANS TO CONTROL, REGULATE A...
# 37983  YES ON 62, NO ON 66. REPLACE THE COSTLY, FAILE...
# 38073  YES ON 62, NO ON 66. REPLACE THE COSTLY, FAILE...
#
#       contributor_firstname            contributor_lastname      amount
# 36927             THOMAS F.                          STEYER  11300000.0
# 30170                THOMAS                          STEYER  10500000.0
# 38463                  SEAN  PARKER AND AFFILIATED ENTITIES   7250000.0
# 37983              NICHOLAS                         MCKEOWN   3000000.0
# 38073                  REED                        HASTINGS   2000000.0
